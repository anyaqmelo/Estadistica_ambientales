# %%
def import_csv(file):
    import pandas as pd 
    return pd.read_csv(file)

# %%
path = "Terminos_lagoon_TA_.csv"

# %%
CO2Data = import_csv(path)

# %% [markdown]
# Exploración de datos

# %%
print(CO2Data.shape)
# Out:
# (106, 21)

# %%
print(CO2Data.columns)
# Out:
# Index(['sample', 'date', 'estuary', 'area', 'station', 'layer_depth', 'season',
#        'chlorophy_microg_l', 'cond_microsiemens_cm', 'depth_m',
#        'do_percent_sat', 'do_mg_l', 'sal_psu', 'sp_cond_microsiemens_cm',
#        'turbidity_fnu', 'temp_c', 'latitude', 'longitude', 'dic_micromol_kg',
#        'ta_micromol_kg', 'dummy_data'],
#       dtype='object')

# %%
ta = CO2Data['ta_micromol_kg']

# %%
dic = CO2Data['dic_micromol_kg']

# %%
dic_ta = CO2Data[['dic_micromol_kg', 'ta_micromol_kg']]

# %%
dic_ta.plot()
# Out:
# <Axes: >

# %%
CO2Data_rainy = CO2Data[CO2Data['season'] == "Rainy"]

# %%
CO2Data_rainy
# Out:
#     sample        date     estuary   area station layer_depth season  \
# 36  CDL01S  26/11/2020  Candelaria  River   CDL01     Surface  Rainy
# 37  CDL01F  26/11/2020  Candelaria  River   CDL01      Bottom  Rainy
# 38  CDL02S  26/11/2020  Candelaria  River   CDL02     Surface  Rainy
# 39  CDL02F  26/11/2020  Candelaria  River   CDL02      Bottom  Rainy
# 40  CDL03S  26/11/2020  Candelaria  River   CDL03     Surface  Rainy
# 41  CDL04S  26/11/2020  Candelaria  Plume   CDL04     Surface  Rainy
# 42  CDL04F  26/11/2020  Candelaria  Plume   CDL04      Bottom  Rainy
# 43  CDL05S  26/11/2020  Candelaria  Plume   CDL05     Surface  Rainy
# 44  CDL05F  26/11/2020  Candelaria  Plume   CDL05      Bottom  Rainy
# 45  CDL06S  26/11/2020  Candelaria  Plume   CDL06     Surface  Rainy
# 46  CDL07S  26/11/2020  Candelaria  Coast   CDL07     Surface  Rainy
# 47  CDL07F  26/11/2020  Candelaria  Coast   CDL07      Bottom  Rainy
# 48  CDL08S  26/11/2020  Candelaria  Coast   CDL08     Surface  Rainy
# ...

# %%
CO2Data_sin_candelaria = CO2Data[CO2Data['estuary'] != 'Candelaria']

# %%
CO2Data_sin_candelaria
# Out:
#      sample        date   estuary   area station layer_depth season  \
# 18   PLZ01S  04/03/2020  Palizada  River   PLZ01     Surface    Dry
# 19   PLZ01F  04/03/2020  Palizada  River   PLZ01      Bottom    Dry
# 20   PLZ02S  04/03/2020  Palizada  River   PLZ02     Surface    Dry
# 21   PLZ02F  04/03/2020  Palizada  River   PLZ02      Bottom    Dry
# 22   PLZ03S  04/03/2020  Palizada  River   PLZ03     Surface    Dry
# 23   PLZ03F  04/03/2020  Palizada  River   PLZ03      Bottom    Dry
# 24   PLZ04S  04/03/2020  Palizada  Plume   PLZ04     Surface    Dry
# 25   PLZ04F  04/03/2020  Palizada  Plume   PLZ04      Bottom    Dry
# 26   PLZ05S  04/03/2020  Palizada  Plume   PLZ05     Surface    Dry
# 27   PLZ05F  04/03/2020  Palizada  Plume   PLZ05      Bottom    Dry
# 28   PLZ06S  04/03/2020  Palizada  Plume   PLZ06     Surface    Dry
# 29   PLZ06F  04/03/2020  Palizada  Plume   PLZ06      Bottom    Dry
# 30   PLZ07S  04/03/2020  Palizada  Coast   PLZ07     Surface    Dry
# ...

# %%
CO2Data_surface = CO2Data[CO2Data['depth_m'] <= 0.5]

# %%
CO2Data_surface
# Out:
#      sample        date     estuary   area station layer_depth season  \
# 0    CDL01S  05/03/2020  Candelaria  River   CDL01     Surface    Dry
# 2    CDL02S  05/03/2020  Candelaria  River   CDL02     Surface    Dry
# 4    CDL03S  05/03/2020  Candelaria  River   CDL03     Surface    Dry
# 6    CDL04S  05/03/2020  Candelaria  Plume   CDL04     Surface    Dry
# 8    CDL05S  05/03/2020  Candelaria  Plume   CDL05     Surface    Dry
# 10   CDL06S  05/03/2020  Candelaria  Plume   CDL06     Surface    Dry
# 12   CDL07S  05/03/2020  Candelaria  Coast   CDL07     Surface    Dry
# 14   CDL08S  05/03/2020  Candelaria  Coast   CDL08     Surface    Dry
# 20   PLZ02S  04/03/2020    Palizada  River   PLZ02     Surface    Dry
# 22   PLZ03S  04/03/2020    Palizada  River   PLZ03     Surface    Dry
# 24   PLZ04S  04/03/2020    Palizada  Plume   PLZ04     Surface    Dry
# 26   PLZ05S  04/03/2020    Palizada  Plume   PLZ05     Surface    Dry
# ...
